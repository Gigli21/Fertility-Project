# %%
# Data analysis phase
# Import all the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Display all the columns of the dataframe
pd.pandas.set_option('display.max_columns', None)
pd.pandas.set_option('display.max_rows', None)

# %%
df = pd.read_csv('fertility.csv')

# %%
#check the size of the data
print(df.shape)
# Out:
# (100, 10)

# %%
#print the top 5 records
df.head(20)
# Out:
#     Season  Age Childish diseases Accident or serious trauma  \
# 0   spring   30                no                        yes
# 1   spring   35               yes                         no
# 2   spring   27               yes                         no
# 3   spring   32                no                        yes
# 4   spring   30               yes                        yes
# 5   spring   30               yes                         no
# 6   spring   30                no                         no
# 7   spring   36               yes                        yes
# 8     fall   30                no                         no
# 9     fall   29               yes                         no
# 10    fall   30               yes                        yes
# 11    fall   32               yes                        yes
# 12    fall   32               yes                        yes
# 13    fall   33               yes                         no
# 14    fall   35               yes                        yes
# 15    fall   33               yes                        yes
# 16    fall   30               yes                         no
# 17    fall   30               yes                         no
# 18    fall   32               yes                        yes
# 19    fall   30               yes                         no
#
#    Surgical intervention High fevers in the last year  \
# 0                    yes       more than 3 months ago
# 1                    yes       more than 3 months ago
# 2                     no       more than 3 months ago
# 3                    yes       more than 3 months ago
# 4                     no       more than 3 months ago
# 5                    yes       more than 3 months ago
# 6                     no       less than 3 months ago
# 7                    yes       more than 3 months ago
# 8                    yes       more than 3 months ago
# 9                     no       more than 3 months ago
# 10                    no       less than 3 months ago
# 11                   yes       more than 3 months ago
# 12                   yes       more than 3 months ago
# 13                    no       more than 3 months ago
# 14                   yes       more than 3 months ago
# 15                    no       more than 3 months ago
# 16                   yes       more than 3 months ago
# 17                   yes       more than 3 months ago
# 18                   yes       more than 3 months ago
# 19                    no       more than 3 months ago
#
#    Frequency of alcohol consumption Smoking habit  \
# 0                       once a week    occasional
# 1                       once a week         daily
# 2              hardly ever or never         never
# 3              hardly ever or never         never
# 4                       once a week         never
# 5                       once a week    occasional
# 6                       once a week         never
# 7              several times a week         never
# 8                       once a week         never
# 9              hardly ever or never         never
# 10                      once a week    occasional
# 11             several times a week    occasional
# 12                      once a week         daily
# 13             hardly ever or never         never
# 14              several times a day         never
# 15             hardly ever or never         daily
# 16             hardly ever or never         never
# 17                      once a week         never
# 18             hardly ever or never         daily
# 19                      once a week         daily
#
#     Number of hours spent sitting per day Diagnosis
# 0                                      16    Normal
# 1                                       6   Altered
# 2                                       9    Normal
# 3                                       7    Normal
# 4                                       9   Altered
# 5                                       9    Normal
# 6                                       8    Normal
# 7                                       7    Normal
# 8                                       5    Normal
# 9                                       5    Normal
# 10                                      6    Normal
# 11                                      2    Normal
# 12                                      5    Normal
# 13                                      7    Normal
# 14                                      5    Normal
# 15                                      9    Normal
# 16                                      7    Normal
# 17                                      5   Altered
# 18                                      5    Normal
# 19                                      7   Altered

# %%
#check for missing values
df.isnull().sum()
# Out:
# Season                                   0
# Age                                      0
# Childish diseases                        0
# Accident or serious trauma               0
# Surgical intervention                    0
# High fevers in the last year             0
# Frequency of alcohol consumption         0
# Smoking habit                            0
# Number of hours spent sitting per day    0
# Diagnosis                                0
# dtype: int64

# %% [markdown]
# **Numerical variables**

# %%
#list of numerical variables
numerical_features = [feature for feature in df.columns if df[feature].dtypes != 'O']
print('Number of numerical variables: ', len(numerical_features))
# Out:
# Number of numerical variables:  2

# %%
#visualise the numerical variables
df[numerical_features].head()
# Out:
#    Age  Number of hours spent sitting per day
# 0   30                                     16
# 1   35                                      6
# 2   27                                      9
# 3   32                                      7
# 4   30                                      9

# %%
#check number of unique values for all features
df.nunique()
# Out:
# Season                                    4
# Age                                      10
# Childish diseases                         2
# Accident or serious trauma                2
# Surgical intervention                     2
# High fevers in the last year              3
# Frequency of alcohol consumption          5
# Smoking habit                             3
# Number of hours spent sitting per day    14
# Diagnosis                                 2
# dtype: int64

# %%
# check over the entire dataframe
df
# Out:
#     Season  Age Childish diseases Accident or serious trauma  \
# 0   spring   30                no                        yes
# 1   spring   35               yes                         no
# 2   spring   27               yes                         no
# 3   spring   32                no                        yes
# 4   spring   30               yes                        yes
# 5   spring   30               yes                         no
# 6   spring   30                no                         no
# 7   spring   36               yes                        yes
# 8     fall   30                no                         no
# 9     fall   29               yes                         no
# 10    fall   30               yes                        yes
# 11    fall   32               yes                        yes
# 12    fall   32               yes                        yes
# 13    fall   33               yes                         no
# 14    fall   35               yes                        yes
# 15    fall   33               yes                        yes
# 16    fall   30               yes                         no
# 17    fall   30               yes                         no
# 18    fall   32               yes                        yes
# 19    fall   30               yes                         no
# 20    fall   30                no                         no
# 21    fall   32               yes                         no
# 22    fall   30               yes                        yes
# 23    fall   30               yes                         no
# 24    fall   28               yes                         no
# 25    fall   30               yes                         no
# 26    fall   30               yes                         no
# 27    fall   32               yes                        yes
# 28    fall   28                no                         no
# 29    fall   30                no                         no
# 30    fall   29               yes                         no
# 31    fall   28               yes                         no
# 32    fall   30                no                         no
# 33    fall   28               yes                        yes
# 34    fall   28               yes                        yes
# 35  winter   32               yes                        yes
# 36  winter   32               yes                         no
# 37  winter   28               yes                         no
# 38  winter   30                no                         no
# 39  winter   30               yes                         no
# 40  winter   28               yes                        yes
# 41  winter   28               yes                        yes
# 42  winter   28               yes                         no
# 43  winter   28               yes                         no
# 44  winter   28               yes                        yes
# 45  winter   28               yes                         no
# 46  spring   28               yes                         no
# 47  spring   31               yes                        yes
# 48  spring   30               yes                        yes
# 49  spring   32               yes                        yes
# 50  spring   30               yes                         no
# 51  spring   28               yes                        yes
# 52  spring   28               yes                        yes
# 53  spring   28               yes                        yes
# 54  spring   29               yes                         no
# 55  spring   28               yes                         no
# 56  spring   28               yes                        yes
# 57  spring   30               yes                        yes
# 58  spring   28               yes                        yes
# 59    fall   28                no                         no
# 60    fall   28                no                         no
# 61  winter   30               yes                         no
# 62  winter   29               yes                        yes
# 63  winter   28               yes                         no
# 64  winter   28               yes                         no
# 65  spring   28                no                         no
# 66  spring   27               yes                        yes
# 67  spring   27               yes                         no
# 68  spring   27               yes                         no
# 69  spring   27               yes                         no
# 70  spring   27               yes                        yes
# 71  summer   30               yes                         no
# 72    fall   28               yes                         no
# 73  winter   27               yes                         no
# 74  winter   28               yes                         no
# 75  winter   32               yes                         no
# 76  winter   32               yes                         no
# 77  winter   31               yes                        yes
# 78  winter   28               yes                        yes
# 79  winter   36               yes                         no
# 80  spring   35               yes                        yes
# 81  winter   33               yes                        yes
# 82  spring   35               yes                         no
# 83  spring   33               yes                        yes
# 84  spring   32               yes                         no
# 85  spring   34               yes                        yes
# 86  spring   32               yes                        yes
# 87  spring   32               yes                        yes
# 88  spring   33               yes                        yes
# 89  spring   33               yes                        yes
# 90  spring   33               yes                        yes
# 91  summer   32               yes                         no
# 92  summer   32               yes                        yes
# 93  summer   32               yes                         no
# 94    fall   28               yes                         no
# 95  winter   30               yes                         no
# 96  winter   29               yes                         no
# 97  winter   30               yes                        yes
# 98  winter   30               yes                         no
# 99  winter   30                no                        yes
#
#    Surgical intervention High fevers in the last year  \
# 0                    yes       more than 3 months ago
# 1                    yes       more than 3 months ago
# 2                     no       more than 3 months ago
# 3                    yes       more than 3 months ago
# 4                     no       more than 3 months ago
# 5                    yes       more than 3 months ago
# 6                     no       less than 3 months ago
# 7                    yes       more than 3 months ago
# 8                    yes       more than 3 months ago
# 9                     no       more than 3 months ago
# 10                    no       less than 3 months ago
# 11                   yes       more than 3 months ago
# 12                   yes       more than 3 months ago
# 13                    no       more than 3 months ago
# 14                   yes       more than 3 months ago
# 15                    no       more than 3 months ago
# 16                   yes       more than 3 months ago
# 17                   yes       more than 3 months ago
# 18                   yes       more than 3 months ago
# 19                    no       more than 3 months ago
# 20                   yes       more than 3 months ago
# 21                    no       more than 3 months ago
# 22                    no       more than 3 months ago
# 23                   yes       less than 3 months ago
# 24                   yes       more than 3 months ago
# 25                    no       more than 3 months ago
# 26                   yes       more than 3 months ago
# 27                    no                           no
# 28                   yes       more than 3 months ago
# 29                   yes       more than 3 months ago
# 30                   yes       more than 3 months ago
# 31                    no       more than 3 months ago
# 32                    no       more than 3 months ago
# 33                   yes       more than 3 months ago
# 34                   yes       more than 3 months ago
# 35                    no                           no
# 36                   yes       more than 3 months ago
# 37                   yes       more than 3 months ago
# 38                   yes       more than 3 months ago
# 39                    no       more than 3 months ago
# 40                   yes       more than 3 months ago
# 41                    no       more than 3 months ago
# 42                   yes       less than 3 months ago
# 43                    no       more than 3 months ago
# 44                    no                           no
# 45                    no                           no
# 46                    no       more than 3 months ago
# 47                    no       more than 3 months ago
# 48                   yes       more than 3 months ago
# 49                   yes       more than 3 months ago
# 50                   yes       more than 3 months ago
# 51                    no                           no
# 52                    no       more than 3 months ago
# 53                   yes       less than 3 months ago
# 54                   yes       more than 3 months ago
# 55                   yes       more than 3 months ago
# 56                    no       more than 3 months ago
# 57                   yes       less than 3 months ago
# 58                    no       more than 3 months ago
# 59                    no                           no
# 60                    no                           no
# 61                    no                           no
# 62                   yes       more than 3 months ago
# 63                    no                           no
# 64                    no                           no
# 65                   yes       more than 3 months ago
# 66                    no       less than 3 months ago
# 67                    no                           no
# 68                    no                           no
# 69                   yes       less than 3 months ago
# 70                    no       less than 3 months ago
# 71                    no                           no
# 72                    no                           no
# 73                    no                           no
# 74                    no                           no
# 75                   yes                           no
# 76                   yes                           no
# 77                   yes                           no
# 78                    no                           no
# 79                   yes                           no
# 80                    no                           no
# 81                   yes                           no
# 82                    no                           no
# 83                   yes                           no
# 84                    no                           no
# 85                    no       more than 3 months ago
# 86                   yes       more than 3 months ago
# 87                   yes                           no
# 88                   yes       more than 3 months ago
# 89                   yes       more than 3 months ago
# 90                   yes                           no
# 91                    no       more than 3 months ago
# 92                    no       more than 3 months ago
# 93                   yes       more than 3 months ago
# 94                    no       more than 3 months ago
# 95                    no       more than 3 months ago
# 96                    no       more than 3 months ago
# 97                   yes       more than 3 months ago
# 98                   yes       more than 3 months ago
# 99                   yes       more than 3 months ago
#
#    Frequency of alcohol consumption Smoking habit  \
# 0                       once a week    occasional
# 1                       once a week         daily
# 2              hardly ever or never         never
# 3              hardly ever or never         never
# 4                       once a week         never
# 5                       once a week    occasional
# 6                       once a week         never
# 7              several times a week         never
# 8                       once a week         never
# 9              hardly ever or never         never
# 10                      once a week    occasional
# 11             several times a week    occasional
# 12                      once a week         daily
# 13             hardly ever or never         never
# 14              several times a day         never
# 15             hardly ever or never         daily
# 16             hardly ever or never         never
# 17                      once a week         never
# 18             hardly ever or never         daily
# 19                      once a week         daily
# 20                      once a week         never
# 21             several times a week    occasional
# 22                      once a week         never
# 23             hardly ever or never         never
# 24             hardly ever or never         never
# 25             hardly ever or never         never
# 26             several times a week         never
# 27             several times a week         never
# 28             hardly ever or never         never
# 29             several times a week    occasional
# 30             hardly ever or never         never
# 31             hardly ever or never         never
# 32             hardly ever or never         never
# 33                      once a week    occasional
# 34             hardly ever or never         never
# 35             several times a week         never
# 36             hardly ever or never         never
# 37             hardly ever or never         never
# 38             several times a week    occasional
# 39             hardly ever or never         never
# 40                      once a week         daily
# 41                      once a week         daily
# 42                      once a week         daily
# 43             hardly ever or never         never
# 44             hardly ever or never    occasional
# 45             hardly ever or never    occasional
# 46             hardly ever or never         never
# 47             several times a week         daily
# 48                      once a week         never
# 49             several times a week         never
# 50                      once a week         never
# 51             hardly ever or never         never
# 52                      once a week    occasional
# 53                      once a week    occasional
# 54             hardly ever or never         never
# 55                      once a week         daily
# 56                      once a week    occasional
# 57             hardly ever or never         never
# 58                        every day         daily
# 59                      once a week         daily
# 60                      once a week    occasional
# 61             hardly ever or never         daily
# 62             several times a week         never
# 63             hardly ever or never         never
# 64                      once a week         never
# 65             hardly ever or never         never
# 66                      once a week    occasional
# 67             hardly ever or never         never
# 68                      once a week    occasional
# 69                      once a week         never
# 70                      once a week    occasional
# 71             hardly ever or never         never
# 72             several times a week    occasional
# 73                      once a week         never
# 74                      once a week         never
# 75             hardly ever or never         daily
# 76             several times a week    occasional
# 77                      once a week         never
# 78                      once a week         never
# 79             several times a week    occasional
# 80             hardly ever or never         never
# 81                      once a week    occasional
# 82             several times a week         never
# 83             hardly ever or never         never
# 84             hardly ever or never         daily
# 85             several times a week         daily
# 86             several times a week         daily
# 87                      once a week         daily
# 88             hardly ever or never         never
# 89             hardly ever or never         daily
# 90                      once a week         never
# 91             hardly ever or never         daily
# 92                      once a week         never
# 93                      once a week         never
# 94             several times a week         daily
# 95             hardly ever or never         never
# 96                      once a week    occasional
# 97             hardly ever or never         never
# 98             hardly ever or never    occasional
# 99             several times a week         never
#
#     Number of hours spent sitting per day Diagnosis
# 0                                      16    Normal
# 1                                       6   Altered
# 2                                       9    Normal
# 3                                       7    Normal
# 4                                       9   Altered
# 5                                       9    Normal
# 6                                       8    Normal
# 7                                       7    Normal
# 8                                       5    Normal
# 9                                       5    Normal
# 10                                      6    Normal
# 11                                      2    Normal
# 12                                      5    Normal
# 13                                      7    Normal
# 14                                      5    Normal
# 15                                      9    Normal
# 16                                      7    Normal
# 17                                      5   Altered
# 18                                      5    Normal
# 19                                      7   Altered
# 20                                      5    Normal
# 21                                      5    Normal
# 22                                      5    Normal
# 23                                      8   Altered
# 24                                     11    Normal
# 25                                      5    Normal
# 26                                      7   Altered
# 27                                      7   Altered
# 28                                      3    Normal
# 29                                      9   Altered
# 30                                     11    Normal
# 31                                      8    Normal
# 32                                     11    Normal
# 33                                      8    Normal
# 34                                     11    Normal
# 35                                      7    Normal
# 36                                      5    Normal
# 37                                     11    Normal
# 38                                      9   Altered
# 39                                      6    Normal
# 40                                      9    Normal
# 41                                      9    Normal
# 42                                      9    Normal
# 43                                      8    Normal
# 44                                      6    Normal
# 45                                      8    Normal
# 46                                     11    Normal
# 47                                      3    Normal
# 48                                      6    Normal
# 49                                      3    Normal
# 50                                    342    Normal
# 51                                     14    Normal
# 52                                      9    Normal
# 53                                      3    Normal
# 54                                     11    Normal
# 55                                      3    Normal
# 56                                     14    Normal
# 57                                     14    Normal
# 58                                     11    Normal
# 59                                      8    Normal
# 60                                     18    Normal
# 61                                      5    Normal
# 62                                      7    Normal
# 63                                      9    Normal
# 64                                      6    Normal
# 65                                     10    Normal
# 66                                     16    Normal
# 67                                      8    Normal
# 68                                      6    Normal
# 69                                      9    Normal
# 70                                     16   Altered
# 71                                      6    Normal
# 72                                      9    Normal
# 73                                      8    Normal
# 74                                     11    Normal
# 75                                      5    Normal
# 76                                     10    Normal
# 77                                      3    Normal
# 78                                      7    Normal
# 79                                      5    Normal
# 80                                     11    Normal
# 81                                      3    Normal
# 82                                      3    Normal
# 83                                      5    Normal
# 84                                      1   Altered
# 85                                      6    Normal
# 86                                      5    Normal
# 87                                      5    Normal
# 88                                      6    Normal
# 89                                      7    Normal
# 90                                      7    Normal
# 91                                      1    Normal
# 92                                      7    Normal
# 93                                      8   Altered
# 94                                      9    Normal
# 95                                      9    Normal
# 96                                      9    Normal
# 97                                      6    Normal
# 98                                      3    Normal
# 99                                      3    Normal

# %%
#get the unique values for the feature 'Age'
df['Age'].unique()
# Out:
# array([30, 35, 27, 32, 36, 29, 33, 28, 31, 34])
